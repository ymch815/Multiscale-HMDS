# %%
import numpy as np

# %%
np.load('../embeddings/bio-diseasome_10_poincare.npy')
# Out:
# array([[-0.02195915, -0.33361752, -0.13675253, ..., -0.39621362,
#          0.42056178, -0.45258247],
#        [-0.12590821,  0.20384394, -0.33190322, ..., -0.20071961,
#          0.36488551, -0.65206216],
#        [-0.19811938, -0.54674352,  0.35002118, ..., -0.35886413,
#         -0.50729661, -0.24888003],
#        ...,
#        [ 0.20207987, -0.16013603,  0.20630159, ...,  0.16112962,
#         -0.55536304,  0.47724281],
#        [ 0.44951142,  0.34511525,  0.56621524, ...,  0.3229268 ,
#          0.17909653,  0.20903856],
#        [ 0.41510353,  0.25440876,  0.50750592, ...,  0.39674318,
#         -0.20300623,  0.38718013]])

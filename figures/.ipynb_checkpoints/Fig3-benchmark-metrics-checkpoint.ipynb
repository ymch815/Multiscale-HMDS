# %%
# benchmark metric comparison
import pandas as pd
import seaborn as sn
from glob import glob
import pylab as plt
import numpy as np

import sys
sys.path.append('../')
import MHMDS.embed_funs as emb

from scipy import stats

from scipy.optimize import minimize

# %%
# 3d data not include ToggleSwitch, because it is only 2d

# if want to plot all 6 datasets:
dataset_names_2d = ['ToggleSwitch','Krumsiek11','Paul_PCA100','Olsson_PCA100',
                 'Celegans_10k_PCA100','Celegans_40k_PCA100']
dataset_names_3d = ['Krumsiek11','Paul_PCA100','Olsson_PCA100',
                 'Celegans_10k_PCA100','Celegans_40k_PCA100']

# if want to plot two datasets in the main figure
# dataset_names_2d = ['Paul_PCA100','Celegans_40k_PCA100']
# dataset_names_3d = ['Paul_PCA100','Celegans_40k_PCA100']

# %%
# load embedding metrics from competing method
phatelist_3d = [pd.read_csv('../Competing-Methods/phate/result/metrics_FeatMat_%s_nd_3.csv'%(name)
                         ,index_col=0) for name in dataset_names_3d]
phatelist_2d = [pd.read_csv('../Competing-Methods/phate/result/metrics_FeatMat_%s_nd_2.csv'%(name)
                         ,index_col=0) for name in dataset_names_2d]

# %%
scanpylist_2d = [pd.read_csv(glob('../Competing-Methods/scanpy/result/metrics_FeatMat_%s_nn_*_nd_2.csv'%(name))[0],
           index_col=0) for name in dataset_names_2d]

# %%
scanpylist_3d = [pd.read_csv(glob('../Competing-Methods/scanpy/result/metrics_FeatMat_%s_nn_*_nd_2.csv'%(name))[0],
           index_col=0).iloc[[0,2,3],:] for name in dataset_names_3d]
# method in scanpy: tsne and ForceAltlas only has 2d, so exclude them when loading 3d

# %%
# poincare map is only 2d
poincaremaplist = [pd.read_csv(glob('../Competing-Methods/poincaremap/result/metric_%s_*.csv'%(name))[0]) 
                   for name in dataset_names_2d]
for df in poincaremaplist:
    df['Method'] = 'PoincareMap'

# %%
# load embedding metrics from mhmds - 3d
mhmdslist_3d = [pd.read_csv(glob('../MultiscalehMDS_feature/result/FeatMat_%s/benchmark/*Nd_3*metrics.csv'%(name))[0],
                        index_col=0).iloc[:,:4] for name in dataset_names_3d]
for i,df in enumerate(mhmdslist_3d):
    if pd.isna(df.iloc[-2,1]):
        mhmdslist_3d[i] = df.iloc[1:2,:]
    else:
        mhmdslist_3d[i] = df.iloc[2:3,:]
    mhmdslist_3d[i]['Step'] = 'M-HMDS'
    mhmdslist_3d[i].rename({'Step':'Method','corr':'Corr'},axis=1,inplace=True)
# Out:
# /var/folders/x4/m6sn1g5s4yjb6ybj1mpz8c600000gn/T/ipykernel_32484/1724350067.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mhmdslist_3d[i]['Step'] = 'M-HMDS'
# /var/folders/x4/m6sn1g5s4yjb6ybj1mpz8c600000gn/T/ipykernel_32484/1724350067.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mhmdslist_3d[i].rename({'Step':'Method','corr':'Corr'},axis=1,inplace=True)

# %%
# load embedding metrics from mhmds - 2d
mhmdslist_2d = [pd.read_csv(glob('../MultiscalehMDS_feature/result/FeatMat_%s/benchmark/*Nd_2*metrics.csv'%(name))[0],
                        index_col=0).iloc[:,:4] for name in dataset_names_2d]
for i,df in enumerate(mhmdslist_2d):
    if pd.isna(df.iloc[-2,1]):
        mhmdslist_2d[i] = df.iloc[1:2,:]
    else:
        mhmdslist_2d[i] = df.iloc[2:3,:]
    mhmdslist_2d[i]['Step'] = 'M-HMDS'
    mhmdslist_2d[i].rename({'Step':'Method','corr':'Corr'},axis=1,inplace=True)
# Out:
# /var/folders/x4/m6sn1g5s4yjb6ybj1mpz8c600000gn/T/ipykernel_32484/1468246367.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mhmdslist_2d[i]['Step'] = 'M-HMDS'
# /var/folders/x4/m6sn1g5s4yjb6ybj1mpz8c600000gn/T/ipykernel_32484/1468246367.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mhmdslist_2d[i].rename({'Step':'Method','corr':'Corr'},axis=1,inplace=True)

# %%
savepath = './'

# %%
# plot each: 2d
palette ={"PoincareMap": "C0", "PHATE": "C1", "ForceAtlas2": "C2", 
          'umap':'C3','t-sne':'C4','DiffMap':'C5','SIMLR':'C6',
          'SAUCIE':'C7','PCA':'C8','M-HMDS':'k'}
markers = {"PoincareMap": "o", "PHATE": "o", "ForceAtlas2": "o", 
          'umap':'o','t-sne':'o','DiffMap':'o','SIMLR':'o',
          'SAUCIE':'o','PCA':'o','M-HMDS':'^'}
fig,axs = plt.subplots(2,3,figsize=(12,6))
axs = axs.flatten()
for i in range(len(dataset_names_2d)):
#     df_toplot = pd.concat([phatelist[i],scanpylist[i],mhmdslist[i]],axis=0)
    df_toplot = pd.concat([phatelist_2d[i],scanpylist_2d[i],poincaremaplist[i],mhmdslist_2d[i]],axis=0)
    sn.scatterplot(data=df_toplot,ax=axs[i],x='Qlocal',y='Qglobal',hue='Method',s=200,palette=palette, style = 'Method',markers=markers)
    axs[i].set_title(dataset_names_2d[i],fontsize=15)
    axs[i].set_xlabel('')
    axs[i].set_ylabel('')
    axs[i].tick_params(axis="x", labelsize=12)  
    axs[i].tick_params(axis="y", labelsize=12)
    
#     plt.xlabel('Correlation',fontsize=15)
    
    axs[i].legend([],[], frameon=False)
#     plt.axis('equal')
    if i!= 0:
        axs[i].set_xlim([np.mean(df_toplot.Qlocal)-0.13,np.mean(df_toplot.Qlocal)+0.13])
#     axs[i].set_ylim([0,1])
axs[2].legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0,fontsize=15)
axs[0].set_ylabel('Bad <- $Q_{global}$ -> Good',fontsize=15)
axs[3].set_ylabel('Bad <- $Q_{global}$ -> Good',fontsize=15)
axs[4].set_xlabel('Bad <- $Q_{local}$ -> Good',fontsize=15)

plt.tight_layout()
# plt.savefig(savepath+'Qs_2d.eps',format='eps')

# %%
# plot each: 3d
palette ={"PoincareMap": "C0", "PHATE": "C1", "ForceAtlas2": "C2", 
          'umap':'C3','t-sne':'C4','DiffMap':'C5','SIMLR':'C6',
          'SAUCIE':'C7','PCA':'C8','M-HMDS':'k'}
markers = {"PoincareMap": "o", "PHATE": "o", "ForceAtlas2": "o", 
          'umap':'o','t-sne':'o','DiffMap':'o','SIMLR':'o',
          'SAUCIE':'o','PCA':'o','M-HMDS':'^'}
fig,axs = plt.subplots(2,3,figsize=(12,6))
axs = axs.flatten()
for i in range(len(dataset_names_3d)):
#     df_toplot = pd.concat([phatelist[i],scanpylist[i],mhmdslist[i]],axis=0)
    df_toplot = pd.concat([phatelist_3d[i],scanpylist_3d[i],mhmdslist_3d[i]],axis=0)
    sn.scatterplot(data=df_toplot,ax=axs[i],x='Qlocal',y='Qglobal',hue='Method',s=200,palette=palette, style = 'Method',markers=markers)
    axs[i].set_title(dataset_names_3d[i],fontsize=15)
    axs[i].set_xlabel('')
    axs[i].set_ylabel('')
    axs[i].tick_params(axis="x", labelsize=12)  
    axs[i].tick_params(axis="y", labelsize=12)
    
#     plt.xlabel('Correlation',fontsize=15)
    
    axs[i].legend([],[], frameon=False)
#     plt.axis('equal')
    if i!= 0:
        axs[i].set_xlim([np.mean(df_toplot.Qlocal)-0.13,np.mean(df_toplot.Qlocal)+0.13])
#     axs[i].set_ylim([0,1])
axs[2].legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0,fontsize=15)
axs[0].set_ylabel('Bad <- $Q_{global}$ -> Good',fontsize=15)
axs[3].set_ylabel('Bad <- $Q_{global}$ -> Good',fontsize=15)
axs[4].set_xlabel('Bad <- $Q_{local}$ -> Good',fontsize=15)

plt.tight_layout()
# plt.savefig(savepath+'Qs_3d.eps',format='eps')

# %%
# correlation - 2d
fig,axs = plt.subplots(2,3,figsize=(15,8))
axs = axs.flatten()
for i in range(len(dataset_names_2d)):
    df_toplot = pd.concat([phatelist_2d[i],scanpylist_2d[i],poincaremaplist[i],mhmdslist_2d[i]],axis=0)
    sn.barplot(data=df_toplot,x='Method',y='Corr',hue='Method',palette=palette,ax=axs[i])
    axs[i].set_title(dataset_names_2d[i],fontsize=15)
    axs[i].set_xlabel('',fontsize=15)
    axs[i].set_ylabel('',fontsize=15)
    
    axs[i].tick_params(axis="x", labelsize=15,rotation=45)  
    axs[i].tick_params(axis="y", labelsize=15)
    
#     plt.xlabel('Correlation',fontsize=15)
    

#     plt.legend(fontsize=10)
#     plt.axis('equal')
axs[0].set_ylabel('Correlation',fontsize=15)
axs[3].set_ylabel('Correlation',fontsize=15)
axs[4].set_xlabel('Method',fontsize=15)
plt.tight_layout()
# plt.savefig(savepath+'corrs_2d.eps',format='eps')

# %%
# correlation - 3d
fig,axs = plt.subplots(2,3,figsize=(15,8))
axs = axs.flatten()
for i in range(len(dataset_names_3d)):
    df_toplot = pd.concat([phatelist_3d[i],scanpylist_3d[i],mhmdslist_3d[i]],axis=0)
    sn.barplot(data=df_toplot,x='Method',y='Corr',hue='Method',palette=palette,ax=axs[i])
    axs[i].set_title(dataset_names_3d[i],fontsize=15)
    axs[i].set_xlabel('',fontsize=15)
    axs[i].set_ylabel('',fontsize=15)
    
    axs[i].tick_params(axis="x", labelsize=15,rotation=45)  
    axs[i].tick_params(axis="y", labelsize=15)
    
#     plt.xlabel('Correlation',fontsize=15)
    

#     plt.legend(fontsize=10)
#     plt.axis('equal')
axs[0].set_ylabel('Correlation',fontsize=15)
axs[3].set_ylabel('Correlation',fontsize=15)
axs[4].set_xlabel('Method',fontsize=15)
plt.tight_layout()
# plt.savefig(savepath+'corrs_3d.eps',format='eps')

# %%
# visualize C elegans data 40k
# metadata
metadata = pd.read_csv('../data/metadata/Celegans_40k_PCA100_metadata.csv',index_col=0)
metadata.head()
metadata['cell.type'][pd.isna(metadata['cell.type'])]='Unannotated'
# Out:
# /var/folders/x4/m6sn1g5s4yjb6ybj1mpz8c600000gn/T/ipykernel_32484/3325316908.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metadata['cell.type'][pd.isna(metadata['cell.type'])]='Unannotated'

# %%
# poincare map
poincoords = pd.read_csv('../Competing-Methods/poincaremap/result/Celegans_40k_PCA100_PM30sigma=2.00gamma=1.00minkowskipca=0_seed0.csv',header=None)
poincoords.head()
# Out:
#           0         1
# 0  0.622075  0.270626
# 1 -0.047739 -0.707607
# 2 -0.446167  0.889806
# 3  0.727966 -0.374266
# 4 -0.466357  0.783170

# %%
# mhmds
coords = np.loadtxt('../MultiscalehMDS_feature/result/FeatMat_Celegans_40k_PCA100/benchmark/cls_200_Nn_30_Nd_2_min_3_max_500_corr_0_coords_40000.txt')
inds = np.loadtxt('../MultiscalehMDS_feature/result/FeatMat_Celegans_40k_PCA100/benchmark/cls_200_Nn_30_Nd_2_min_3_max_500_corr_0_inds_after_prep.txt')
coords = coords[np.argsort(inds)]

# %%
# recenter

datarc = emb.perform_recenter(coords,np.arange(40000))
# datarc = emb.perform_recenter(coords,np.where(metadata['embryo.time']<150)[0])

# datarc_poin = emb.perform_recenter(np.array(poincoords),np.where(metadata['embryo.time']<150)[0])
datarc_poin = emb.perform_recenter(np.array(poincoords),np.arange(40000))

# datarc = emb.perform_recenter(coords,np.arange(40000))
# Out:
# 11:55:17 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:18 - cmdstanpy - INFO - Chain [1] done processing
# 11:55:18 - cmdstanpy - INFO - Chain [1] start processing
# 11:55:18 - cmdstanpy - INFO - Chain [1] done processing

# %%
# df_pm = pd.concat([metadata.reset_index(),pd.DataFrame(emb.to_native(poincoords))],axis=1)
df_pm = pd.concat([metadata.reset_index(),pd.DataFrame(emb.to_native(datarc_poin))],axis=1)
# df_pm = pd.concat([metadata.reset_index(),pd.DataFrame(datarc_poin)],axis=1)
# df_mhmds = pd.concat([metadata.reset_index(),pd.DataFrame(projected)],axis=1)
# df_mhmds = pd.concat([metadata.reset_index(),pd.DataFrame(emb.to_native(coords))],axis=1)
df_mhmds = pd.concat([metadata.reset_index(),pd.DataFrame(emb.to_native(datarc))],axis=1)
# df_mhmds = pd.concat([metadata.reset_index(),pd.DataFrame(datarc)],axis=1)
fig, axs = plt.subplots(1,2,figsize=(9,4))
sn.scatterplot(data=df_pm, x=0,y=1,hue='embryo.time',palette = 'Spectral',ax=axs[0],s=5)

sn.scatterplot(data=df_mhmds, x=0,y=1,hue='embryo.time',palette = 'Spectral',ax=axs[1],s=5)

norm = plt.Normalize(df_pm['embryo.time'].min(), df_pm['embryo.time'].max())
sm = plt.cm.ScalarMappable(cmap="Spectral", norm=norm)
sm.set_array([])

# Remove the legend and add a colorbar
axs[0].get_legend().remove()
axs[1].get_legend().remove()
plt.colorbar(sm).set_label(label='Embryo Time (mins)',size=15)

axs[0].set_xlabel('Poincare Map - 1', fontsize=15)
axs[0].set_ylabel('Poincare Map - 2', fontsize=15)

axs[1].set_xlabel('Multiscale H-MDS - 1', fontsize=15)
axs[1].set_ylabel('Multiscale H-MDS - 2', fontsize=15)

axs[0].set_title('Poincare Map', fontsize=15)
axs[1].set_title('Multiscale H-MDS', fontsize=15)


for i in range(2):
    axs[i].tick_params(axis="x", labelsize=12)  
    axs[i].tick_params(axis="y", labelsize=12)
    axs[i].set_aspect('equal', adjustable='box')

plt.tight_layout()
# plt.savefig('../summary_note/MHMDS_figures/3/Celegans_2d.eps',format='eps')
# plt.savefig('../summary_note/MHMDS_figures/3/Celegans_2d.png',format='png',dpi=300)
# Out:
# /var/folders/x4/m6sn1g5s4yjb6ybj1mpz8c600000gn/T/ipykernel_32484/666980212.py:20: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   plt.colorbar(sm).set_label(label='Embryo Time (mins)',size=15)

# %%
# cell types: regroup
toplot = metadata.groupby('cell.type').count().iloc[:,1].sort_values(ascending=False)[:15].index

# %%
fig, axs = plt.subplots(1,2,figsize=(14,7))
axs = axs.flatten()
sn.scatterplot(data=df_pm[np.isin(df_pm['cell.type'],toplot)], x=0,y=1,hue='cell.type',ax=axs[0],s=15)
sn.scatterplot(data=df_mhmds[np.isin(df_pm['cell.type'],toplot)], x=0,y=1,hue='cell.type',ax=axs[1],s=15)
axs[1].legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0,fontsize=12,ncols=1)

# Remove the legend and add a colorbar
axs[0].get_legend().remove()

for types in toplot:
    axs[0].annotate(types, xy = np.mean(df_pm[df_pm['cell.type']==types][[0,1]],axis=0),fontsize=10)
for types in toplot:
    axs[1].annotate(types, xy = np.mean(df_mhmds[df_mhmds['cell.type']==types][[0,1]],axis=0),fontsize=10)
    
axs[0].set_xlabel('Poincare Map - 1', fontsize=15)
axs[0].set_ylabel('Poincare Map - 2', fontsize=15)

axs[1].set_xlabel('Multiscale H-MDS - 1', fontsize=15)
axs[1].set_ylabel('Multiscale H-MDS - 2', fontsize=15)

axs[0].set_title('Poincare Map', fontsize=15)
axs[1].set_title('Multiscale H-MDS', fontsize=15)


for i in range(2):
    axs[i].tick_params(axis="x", labelsize=12)  
    axs[i].tick_params(axis="y", labelsize=12)
    axs[i].set_aspect('equal', adjustable='box')

plt.tight_layout()
# plt.savefig('../summary_note/MHMDS_figures/2/Celegans_2d_celltype.eps',format='eps')
# plt.savefig('../summary_note/MHMDS_figures/2/Celegans_2d_celltype.png',format='png',dpi=300)

# %%
# df_pm['radii'] = np.linalg.norm(emb.to_native(poincoords),axis=1)
df_pm['radii'] = np.linalg.norm(emb.to_native(datarc_poin),axis=1)

# df_mhmds['radii'] = np.linalg.norm(emb.to_native(projected),axis=1)
# df_mhmds['radii'] = np.linalg.norm(projected,axis=1)
df_mhmds['radii'] = np.linalg.norm(emb.to_native(datarc),axis=1)
# df_mhmds['radii'] = np.linalg.norm(emb.to_native(coords),axis=1)

# %%
lplot = ['< 100','100-130','130-170','170-210','210-270','270-330','330-390',
         '390-450','450-510','510-580','580-650','> 650']
xx = []
mean_poin = []
mean_mhmds = []
for ind in lplot[:-1]:
    mean_poin.append(np.mean(df_pm[df_pm['embryo.time.bin'] == ind]['radii']))
    mean_mhmds.append(np.mean(df_mhmds[df_mhmds['embryo.time.bin'] == ind]['radii']))
    xx.append(np.mean(df_pm[df_pm['embryo.time.bin'] == ind]['embryo.time']))

# %%
# radius versus embryotime
fig,axs = plt.subplots(2,2,figsize = (10,6),gridspec_kw={'width_ratios': [2,1]})
axs = axs.flatten()
sn.violinplot(data=df_pm[np.isin(df_pm['embryo.time.bin'], lplot)],x='embryo.time.bin',
              y='radii',order=lplot,hue='embryo.time.bin',ax = axs[0],linewidth=1)

sn.violinplot(data=df_mhmds[np.isin(df_mhmds['embryo.time.bin'], lplot)],x='embryo.time.bin',
              y='radii',order=lplot,hue='embryo.time.bin',ax = axs[2],linewidth=1)

# axs[1].plot(xx,mean_poin,'ko')
sn.regplot(data=pd.DataFrame({'x':xx,'y':mean_poin}),x='x',y='y',ax=axs[1])
corr,p  = stats.pearsonr(xx,mean_poin)
if p >= 0.00001:
    axs[1].set_title('corr = %.4f, p = %.5f'%(corr,p),fontsize=15)
else:
    axs[1].set_title('corr = %.4f, p < $10^{-5}$'%(corr),fontsize=15)

# axs[3].plot(xx,mean_mhmds,'ko')
sn.regplot(data=pd.DataFrame({'x':xx,'y':mean_mhmds}),x='x',y='y',ax=axs[3])
corr,p  = stats.pearsonr(xx,mean_mhmds)
if p >= 0.00001:
    axs[3].set_title('corr = %.4f, p = %.5f'%(corr,p),fontsize=15)
else:
    axs[3].set_title('corr = %.4f, p < $10^{-5}$'%(corr),fontsize=15)

for i in [2,3]:
    axs[i].set_xlabel('Embryo Time (mins)',fontsize=15)
    axs[i].tick_params(axis="x", labelsize=15,rotation=45)  
    axs[i].tick_params(axis="y", labelsize=15)
for i in [0,1]:
    axs[i].set_xlabel('',fontsize=15)
    axs[i].set_ylabel('',fontsize=15)
    axs[i].tick_params(axis='x',labelbottom=False,bottom=False)
    axs[i].tick_params(axis="y", labelsize=15)
for i in [0,2]:
    axs[i].set_ylim([-1.5,11])
    axs[i].set_ylabel('Hyperbolic Radius',fontsize=15)


axs[0].set_title('Poincare Map', fontsize=15)
    
axs[2].set_title('Multiscale H-MDS', fontsize=15)
    

plt.tight_layout()

# plt.savefig('../summary_note/MHMDS_figures/3/Celegan_radius_comp.svg',format = 'svg')
